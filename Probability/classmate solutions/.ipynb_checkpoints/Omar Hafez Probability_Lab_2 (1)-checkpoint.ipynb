# %% [markdown]
# # LAB 2: Indepdenece and Random Variables
#
# In this lab you will use python to study the following topics:
#
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt

# %% [markdown]
# # Empirical vs Theoretical probability
# ![image.png](attachment:image.png)

# %% [markdown]
# # Problem 1
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
#type your code here:
n = 1000000
coin1 = np.random.randint(2, size=n)
coin2 = np.random.randint(2, size=n)
event = [1 if (coin1[i]==1 and coin2[i]==1) else 0 for i in range(len(coin1))]

print(np.mean(np.array(event)))


# tests = np.random.randint(2, size=(int(1e6), 2))
# print(tests)
# tests_sum = tests.sum
# 0.249552
# Out:
# 0.250324

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
#type your code here:
# coins = np.random.randint(0,4, size=n)
# event = [1 if coin == 1 else 0 for coin in coins]
coin1 = np.random.randint(2, size=n)
coin2 = np.random.randint(2, size=n)
coin3 = np.random.randint(2, size=n)
event = [1 if (coin1[i]==1 and coin2[i]==0 and coin3[i]==0) or (coin1[i]==0 and coin2[i]==1 and coin3[i]==0) or (coin1[i]==0 and coin2[i]==0 and coin3[i]==1)else 0 for i in range(len(coin1))]
print(np.mean(np.array(event)))


# 0.374306
# Out:
# 0.368

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
#type your code here:
coin1 = np.random.choice([1,0], size=n, p = [0.6, 0.4])
coin2 = np.random.choice([1,0], size=n, p = [0.6, 0.4])
coin3 = np.random.choice([1,0], size=n, p = [0.6, 0.4])
event = [1 if (coin1[i]==1 and coin2[i]==0 and coin3[i]==0) or (coin1[i]==0 and coin2[i]==1 and coin3[i]==0) or (coin1[i]==0 and coin2[i]==0 and coin3[i]==1)else 0 for i in range(len(coin1))]
print(sum(event)/len(event))
# another way to get mean
# print(np.mean(np.array(event)))
# 0.28775
# Out:
# 0.289168

# %% [markdown]
# # Problem 2
#
# The probability of rain in a day is p = 0.5. Give the python code to simulate the probability of rain during weekend (**i.e rain on any one of the 2 weekend days Friday Or Saturday**) (assume independence between raining days). Compare the results with the theoretical probability.

# %%
#type your code here:
friday = np.random.randint(2, size=n)
saturday = np.random.randint(2, size=n)
event = [1 if (friday[i]==1 or saturday[i]==1) else 0 for i in range(n)]
print(np.mean(np.array(event)))

# 0.749331
# Out:
# 0.751

# %% [markdown]
# # Problem 3
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
#type your code here:
n = 1000
dice = np.random.randint(1, 7, size=n)
print('Sample mean:',np.mean(dice))
print('Sample variance:',np.var(dice))
print('Sample standard deviation:',np.var(dice)**.5)

# Sample mean: 3.569
# Sample variance: 2.9041431431431435
# Sample standard deviation: 1.7041546711326245
# Out:
# Sample mean: 3.419
# Sample variance: 2.745439
# Sample standard deviation: 1.6569366312566092
