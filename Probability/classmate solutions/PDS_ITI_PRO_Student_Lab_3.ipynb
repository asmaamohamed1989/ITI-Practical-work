# %% [markdown]
# # LAB 3: Probability Distributions and Central Limit Theorem
#
# In this lab you will use python to study the following topics:
#
# - How to sample from different distributions functions.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for different distributions functions.
# - How to simulate central limit theorem for different distributions functions.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Problem 1
# a) Use the numpy function [numpy.random.normal](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate a standard Gaussian random variable $X$ (zero mean and unit variance).
#
# - Use histogram to plot the estimated PDF of the random variable $X$
# - Compute the true "analytical" PDF of $X$ . Plot the true PDF on the top of the histogram figure.
# - Calculate the sample mean and the sample variance.

# %%
mu = 0
sigma =1
size = 1000000
s = np.random.normal(mu,sigma, size)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
plt.show();
print("Sample mean: {}".format(s.mean()))
print("Sample variance: {}".format(s.var()))
# Out:
# Sample mean: -0.0007466807361413241
# Sample variance: 0.998997416238664

# %% [markdown]
# b) Repeat (a) for a Gaussian random variable $Y$ with $mean=3$ and $variance=4$.

# %%
mu = 3
sigma =2
size = 1000000
s = np.random.normal(mu,sigma, size)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
plt.show();
print("Sample mean: {}".format(s.mean()))
print("Sample variance: {}".format(s.var()))
# Out:
# Sample mean: 2.999942182154324
# Sample variance: 4.0034809316289754

# %% [markdown]
# C) Repeat (a) for an exponential random variable with $\lambda = 1$ using the numpy function [numpy.random.exponential](https://numpy.org/doc/stable/reference/random/generated/numpy.random.exponential.html)

# %%
size=100000
Lambda = 1
s = np.random.exponential(Lambda, size)
count, bins, ignored = plt.hist(s, 100, density=True)
plt.plot(bins, ((1/Lambda)*np.exp(-bins/Lambda)),linewidth=2, color='r')
plt.show();
print("Sample mean: {}".format(s.mean()))
print("Sample variance: {}".format(s.var()))
# Out:
# Sample mean: 1.001985730161436
# Sample variance: 0.9850299341060137

# %% [markdown]
# d) Repeat (a) for an exponential random variable with $\lambda = 0.5$

# %%
size=100000
Lambda = 2
s = np.random.exponential(Lambda, size)
count, bins, ignored = plt.hist(s, 100, density=True)
plt.plot(bins, ((1/Lambda)*np.exp(-bins/Lambda)),linewidth=2, color='r')
plt.show();
print("Sample mean: {}".format(s.mean()))
print("Sample variance: {}".format(s.var()))
# Out:
# Sample mean: 1.9917999461818736
# Sample variance: 3.9156887022719373

# %% [markdown]
# # Problem 2: Practicing the Central Limit Theorem
# Use Python to simulate the Central Limit Theorem for the following random i.i.d variables and check that the higher the number of number the variables, the more the mean of subsets behave like a gaussian random variable.
#
# a) Exponential random variable with $\lambda = 0.5$

# %%
size=10000
Lambda = 2
Population = np.random.exponential(Lambda, size)

means = []
for i in range(1000):
    means.append(np.random.choice(Population, size=2).mean())
plt.hist(means,100)
plt.show();
print("Sample mean is: {}".format(np.array(means).mean()))
print("Sample variance is: {}".format(np.array(means).var()))
# Out:
# Sample mean is: 1.973340154194221
# Sample variance is: 2.0285706766378615

# %%
means = []
for i in range(1000):
    means.append(np.random.choice(Population, size=100).mean())
plt.hist(means,100)
plt.show();
print("Sample mean is: {}".format(np.array(means).mean()))
print("Sample variance is: {}".format(np.array(means).var()))
# Out:
# Sample mean is: 1.9828015310450877
# Sample variance is: 0.037706067146030295

# %%
means = []
for i in range(1000):
    means.append(np.random.choice(Population, size=100000).mean())
plt.hist(means,50)
plt.show();
print("Sample mean is: {}".format(np.array(means).mean()))
print("Sample variance is: {}".format(np.array(means).var()))
# Out:
# Sample mean is: 1.9952619665397067
# Sample variance is: 3.890141106540054e-05

# %% [markdown]
# b) Binomial random variable with $n = 20$ and $p = 0.2$

# %%
n=20
p = 0.2
Population = np.random.binomial(n,p, 100000)

means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=10).mean())
plt.hist(means,30)
plt.show();

# %%
means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=100).mean())
plt.hist(means,30)
plt.show();

# %%
means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=1000).mean())
plt.hist(means,30)
plt.show();

# %%
means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=10000).mean())
plt.hist(means,20)
plt.show();

# %% [markdown]
# c) Uniform random variable with $a = 2$ and $b = 8$

# %%
a= 2
b = 8
Population = np.random.uniform(a,b, 100000)

means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=100).mean())
plt.hist(means,20)
plt.show();

# %%
#type your code here:
means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=1000).mean())
plt.hist(means,20)
plt.show();

# %%
#type your code here:
means = []
for i in range(10000):
    means.append(np.random.choice(Population, size=100000).mean())
plt.hist(means,20)
plt.show();
