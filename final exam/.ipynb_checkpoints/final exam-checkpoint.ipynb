# %% [markdown]
# # part 1
# # question 1

# %%
# Use this cell to set up import statements for all of the packages that you
#   plan to use.
# First, import the necessary packages that we need to analyze 

import numpy as np
import pandas as pd

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing data

#Read adult dataset

df=pd.read_csv('adult.csv')

# showing the first 5 lines of the data

df.head()
# Out:
#    Unnamed: 0  age          workclass  fnlwgt   education  education-num  \
# 0           0   39          State-gov   77516   Bachelors             13
# 1           1   50   Self-emp-not-inc   83311   Bachelors             13
# 2           2   38            Private  215646     HS-grad              9
# 3           3   53            Private  234721        11th              7
# 4           4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# ...

# %%
# look at the shape
df.shape
# Out:
# (32561, 16)

# %%
# some summary statistics

df.describe()
# Out:
#          Unnamed: 0           age        fnlwgt  education-num  capital-gain  \
# count  32561.000000  32561.000000  3.256100e+04   32561.000000  32561.000000
# mean   16280.000000     38.581647  1.897784e+05      10.080679   1077.648844
# std     9399.695394     13.640433  1.055500e+05       2.572720   7385.292085
# min        0.000000     17.000000  1.228500e+04       1.000000      0.000000
# 25%     8140.000000     28.000000  1.178270e+05       9.000000      0.000000
# 50%    16280.000000     37.000000  1.783560e+05      10.000000      0.000000
# 75%    24420.000000     48.000000  2.370510e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  32561.000000    32561.000000
# mean      87.303830       40.437456
# std      402.960219       12.347429
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# ...

# %% [markdown]
# This is summary statistics that shows the mean ,min, max and other statistics calculations

# %%
# check what is Data type of Variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      32561 non-null  int64
#  1   age             32561 non-null  int64
#  2   workclass       32561 non-null  object
#  3   fnlwgt          32561 non-null  int64
#  4   education       32561 non-null  object
#  5   education-num   32561 non-null  int64
#  6   marital-status  32561 non-null  object
#  7   occupation      32561 non-null  object
#  8   relationship    32561 non-null  object
#  9   race            32561 non-null  object
#  10  sex             32561 non-null  object
#  11  capital-gain    32561 non-null  int64
#  12  capital-loss    32561 non-null  int64
#  13  hours-per-week  32561 non-null  int64
#  14  native-country  32561 non-null  object
#  15  income          32561 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# # 1- Define missing

# %%
# Checking for null values
pd.isna(df).sum()
# Out:
# Unnamed: 0        0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# # comment
# we can see that there are no null values in this dataset "adult"

# %%
#check if there is an age with minus or 0 value

df[df["age"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %% [markdown]
# # comment
# From the pervious describe of the dataset , this show that Age column has no negative values or zero values

# %% [markdown]
# # 2 split data

# %%
# sort value based on income
income = df.income.sort_values()
df.groupby('income').groups.keys()
# Out:
# dict_keys([' <=50K', ' >50K'])

# %%
# Get values items from group with value 
data1= style.get_group(' <=50K')
data1.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# Now that we have finished the splitting cleaned data, we can save the cleaned dataframe to another .csv-file.

# %%
df.to_csv('data1.csv')

# %%
df=pd.read_csv('data1.csv')
# showing the first 5 lines of the data

df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  age          workclass  fnlwgt   education  \
# 0           0             0   39          State-gov   77516   Bachelors
# 1           1             1   50   Self-emp-not-inc   83311   Bachelors
# 2           2             2   38            Private  215646     HS-grad
# 3           3             3   53            Private  234721        11th
# 4           4             4   28            Private  338409   Bachelors
#
#    education-num       marital-status          occupation    relationship  \
# 0             13        Never-married        Adm-clerical   Not-in-family
# 1             13   Married-civ-spouse     Exec-managerial         Husband
# 2              9             Divorced   Handlers-cleaners   Not-in-family
# 3              7   Married-civ-spouse   Handlers-cleaners         Husband
# 4             13   Married-civ-spouse      Prof-specialty            Wife
#
#      race      sex  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
#  look at the histogram of the whole data frame 
df.hist(figsize=(20,16));

# %%
# max() will print the maximum entry of each group
style['age'].max()
# Out:
# income
#  <=50K    90
#  >50K     90
# Name: age, dtype: int64

# %%
# max() will print the maximum entry of each group
style.get_group(' <=50K').max()
# Out:
# age                              90
# workclass               Without-pay
# fnlwgt                      1484705
# education              Some-college
# education-num                    16
# marital-status              Widowed
# occupation         Transport-moving
# relationship                   Wife
# race                          White
# sex                            Male
# capital-gain                  41310
# capital-loss                   4356
# hours-per-week                   99
# native-country           Yugoslavia
# income                        <=50K
# dtype: object

# %%
# min() will print the maximum entry of each group
style.get_group(' <=50K').min()
# Out:
# age                                17
# workclass                           ?
# fnlwgt                          12285
# education                        10th
# education-num                       1
# marital-status               Divorced
# occupation                          ?
# relationship                  Husband
# race               Amer-Indian-Eskimo
# sex                            Female
# capital-gain                        0
# capital-loss                        0
# hours-per-week                      1
# native-country                      ?
# income                          <=50K
# dtype: object

# %%
# mean() will print the maximum entry of each group
style.get_group(' <=50K').mean()
# Out:
# age                   36.783738
# fnlwgt            190340.865170
# education-num          9.595065
# capital-gain         148.752468
# capital-loss          53.142921
# hours-per-week        38.840210
# dtype: float64

# %%
# Get values items from group with value  >50K
style.get_group(' >50K')
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32539   71                  ?  287372      Doctorate             16
# 32545   39          Local-gov  111499     Assoc-acdm             12
# 32554   53            Private  321865        Masters             14
# 32557   40            Private  154374        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 7       Married-civ-spouse     Exec-managerial         Husband
# ...

# %% [markdown]
# Now that we have finished the splitting cleaned data, we can save the cleaned dataframe to another .csv-file.

# %%
df.to_csv('data2.csv')

# %%
df=pd.read_csv('data2.csv')
# showing the first 5 lines of the data

df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  age          workclass  fnlwgt  \
# 0           0             0               0   39          State-gov   77516
# 1           1             1               1   50   Self-emp-not-inc   83311
# 2           2             2               2   38            Private  215646
# 3           3             3               3   53            Private  234721
# 4           4             4               4   28            Private  338409
#
#     education  education-num       marital-status          occupation  \
# 0   Bachelors             13        Never-married        Adm-clerical
# 1   Bachelors             13   Married-civ-spouse     Exec-managerial
# 2     HS-grad              9             Divorced   Handlers-cleaners
# 3        11th              7   Married-civ-spouse   Handlers-cleaners
# 4   Bachelors             13   Married-civ-spouse      Prof-specialty
#
#      relationship    race      sex  capital-gain  capital-loss  \
# ...

# %%
# max() will print the maximum entry of each group
style['age'].max()
# Out:
# income
#  <=50K    90
#  >50K     90
# Name: age, dtype: int64

# %%
# min() will print the minimum entry of each group
style.get_group(' <=50K').min()
# Out:
# age                                17
# workclass                           ?
# fnlwgt                          12285
# education                        10th
# education-num                       1
# marital-status               Divorced
# occupation                          ?
# relationship                  Husband
# race               Amer-Indian-Eskimo
# sex                            Female
# capital-gain                        0
# capital-loss                        0
# hours-per-week                      1
# native-country                      ?
# income                          <=50K
# dtype: object

# %%
# max() will print the maximum entry of each group
style.get_group(' <=50K').max()
# Out:
# age                              90
# workclass               Without-pay
# fnlwgt                      1484705
# education              Some-college
# education-num                    16
# marital-status              Widowed
# occupation         Transport-moving
# relationship                   Wife
# race                          White
# sex                            Male
# capital-gain                  41310
# capital-loss                   4356
# hours-per-week                   99
# native-country           Yugoslavia
# income                        <=50K
# dtype: object

# %%
# mean() will print the maximum entry of each group
style.get_group(' <=50K').mean()
# Out:
# age                   36.783738
# fnlwgt            190340.865170
# education-num          9.595065
# capital-gain         148.752468
# capital-loss          53.142921
# hours-per-week        38.840210
# dtype: float64

# %%
education =df["education"]

mode = education.mode()
print(mode)
# Out:
# 0     HS-grad
# dtype: object

# %%
# Fixing name of hours-per-week column because it can make conflict in writing

df.rename(columns = {'hours-per-week': 'hoursperweek'}, inplace = True)

#Inspect the name of column after Fixing its typos

print(df['hoursperweek'].head())
# Out:
# 0    40
# 1    13
# 2    40
# 3    40
# 4    40
# Name: hoursperweek, dtype: int64

# %%
hoursperweek =df["hoursperweek"]

max = hoursperweek.max()
print(max)
# Out:
# 99

# %%
hoursperweek =df["hoursperweek"]

mean = hoursperweek.mean()
print(mean)
# Out:
# 40.437455852092995

# %%
hoursperweek =df["hoursperweek"]

min = hoursperweek.min()
print(min)
# Out:
# 1

# %% [markdown]
# # 3 male income >50k

# %%
df['income'].value_counts(normalize='male')
# Out:
#  <=50K    0.75919
#  >50K     0.24081
# Name: income, dtype: float64

# %% [markdown]
# # 4 Is most frequently for male income in >50k

# %% [markdown]
# These following plots represent that the answer of question 4 is no since most frequently for male income is <50k

# %%
df['income'].value_counts(normalize='male').plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df['income'].value_counts().plot(kind='bar', title = 'Counts by income ')
plt.xlabel('income', fontsize=20)
plt.ylabel('sex', fontsize=20);

# %% [markdown]
# # 5 Is the most frequency for husband's income in >50k ?

# %%
df['relationship'].value_counts().plot();

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df['relationship'].value_counts().plot(kind='bar', title = 'Counts by relationship ')
plt.xlabel('relationship', fontsize=20)
plt.ylabel('income', fontsize=20);

# %% [markdown]
# # comment
# The pervious plots represents that the most frequency for husband's income >50 k

# %% [markdown]
# # part 2
# # question 2

# %%
f = open("steps.txt", "rt")
print(f.read())
# Out:
# 1102
# 9236
# 10643
# 2376
# 6815
# 10394
# 3055
# 3750
# 4181
# 5452
# 10745
# 9896
# 255
# 9596
# 1254
# 2669
# 1267
# 1267
# 1327
# 10207
# 5731
# 8435
# 640
# 5624
# 1062
# 3946
# 3796
# 9381
# 5945
# 10612
# 1970
# 9035
# 1376
# 1919
# 2868
# 5847
# 685
# 10578
# 3477
# 3937
# 5994
# 6971
# 3011
# 4474
# 4344
# 8068
# 6564
# 2659
# 4064
# 1161
# 6830
# 5167
# 5686
# 5352
# 898
# 4316
# 7699
# 6406
# 6466
# 2802
# 1239
# 8162
# 398
# 9908
# 8251
# 8419
# 6245
# 8484
# 9012
# 6318
# 853
# 4031
# 868
# 8776
# 10453
# 1026
# 1984
# 8127
# 5274
# 6937
# 1960
# 9655
# 1279
# 9386
# 6697
# 6326
# 2509
# 7127
# 7802
# 8798
# 6564
# 7220
# 10650
# 3847
# 7485
# 10951
# 3883
# 9456
# 4671
# 2067
# 6871
# 1573
# 8746
# 7473
# 4713
# 1215
# 8486
# 6652
# 4054
# 10304
# 5291
# 2680
# 9108
# 6446
# 1581
# 7607
# 2032
# 7630
# 1106
# 3702
# 986
# 8602
# 556
# 2209
# 3055
# 886
# 5813
# 6513
# 3154
# 1534
# 6271
# 611
# 4001
# 6522
# 3819
# 8396
# 2364
# 9660
# 5937
# 2506
# 9002
# 8586
# 8805
# ...

# %%
f = open("steps.txt", "r")
for x in f:
  print(x)
# Out:
# 1102
#
# 9236
#
# 10643
#
# 2376
#
# 6815
#
# 10394
#
# 3055
#
# 3750
#
# 4181
#
# 5452
#
# 10745
#
# 9896
#
# 255
#
# 9596
#
# 1254
#
# 2669
#
# 1267
#
# 1267
#
# 1327
#
# 10207
#
# 5731
#
# 8435
#
# 640
#
# 5624
#
# 1062
#
# 3946
#
# 3796
#
# 9381
#
# 5945
#
# 10612
#
# 1970
#
# 9035
#
# 1376
#
# 1919
#
# 2868
#
# 5847
#
# 685
#
# 10578
#
# 3477
#
# 3937
#
# 5994
#
# 6971
#
# 3011
#
# 4474
#
# 4344
#
# 8068
#
# 6564
#
# 2659
#
# 4064
#
# 1161
#
# 6830
#
# 5167
#
# 5686
#
# 5352
#
# 898
#
# 4316
#
# 7699
#
# 6406
#
# 6466
#
# 2802
#
# 1239
#
# 8162
#
# 398
#
# 9908
#
# 8251
#
# 8419
#
# 6245
#
# 8484
#
# 9012
#
# 6318
#
# 853
#
# 4031
#
# 868
#
# 8776
#
# 10453
#
# 1026
#
# 1984
#
# 8127
#
# 5274
#
# 6937
#
# 1960
#
# 9655
#
# 1279
#
# 9386
#
# 6697
#
# 6326
#
# 2509
#
# 7127
#
# 7802
#
# 8798
#
# 6564
#
# 7220
#
# 10650
#
# 3847
#
# 7485
#
# 10951
#
# 3883
#
# 9456
#
# 4671
#
# 2067
#
# 6871
#
# 1573
#
# 8746
#
# 7473
#
# 4713
#
# 1215
#
# 8486
#
# 6652
#
# 4054
#
# 10304
#
# 5291
# ...

# %%
L1=np.zeros([sr1,sr1])
for i in range(sr1):
    for j in range(sr1):
            L1[i,j]=abs(s1[i]-s1[j])
L12=np.zeros([sr1,sr2])
for i in range(sr1):
        for j in range(sr2):
            L12[i,j]=abs(s1[i]-s2[j])

L13=np.zeros([sr1,sr3])
for i in range(sr1):
        for j in range(sr3):
            L13[i,j]=abs(s1[i]-s3[j]) 
            
#LL1=np.hstack(L1,L12,L13)
LL1 = np.concatenate((L1,L12,L13),axis=1) 
#print(LL1)
#   
L2=np.zeros([sr2,sr2])
for i in range(sr2):
        for j in range(sr2):
            L2[i,j]=abs(s2[i]-s2[j]) 

L21=np.zeros([sr2,sr1])
for i in range(sr2):
        for j in range(sr1):
            L21[i,j]=abs(s2[i]-s1[j]) 
    
L23=np.zeros([sr2,sr3])
for i in range(sr2):
        for j in range(sr3):
            L23[i,j]=abs(s2[i]-s3[j])  

#LL2=np.hstack(L2,L21,L23)
LL2 = np.concatenate((L21,L2,L23),axis=1)
    #print(LL2)

#     
L3=np.zeros([sr3,sr3])
    for i in range(sr3):
        for j in range(sr3):
            L3[i,j]=abs(s3[i]-s3[j])
    
L31=np.zeros([sr3,sr1])
       for i in range(sr3):
          for j in range(sr1):
            L31[i,j]=abs(s3[i]-s1[j]) 
            L32=np.zeros([sr3,sr2])
            for i in range(sr3):
            for j in range(sr2):
            L32[i,j]=abs(s3[i]-s2[j])
# horizontal concatination    
LL3 = np.concatenate((L31,L32,L3),axis=1)
# print(LL3)
# Out:
#   File "<ipython-input-116-ac52c3d4f1c1>", line 40
#     for i in range(sr3):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # question 3

# %%
#include <iostream >
#include <iomanip >
using namespace std;
int main()
{
//variable declarations
int totalMiles = 0;
int totalGallons = 0;
int miles;
int gallons;
//mpg declarations
Double thisMPG;
Double totalMPG;
cout << "\nEnter miles driven (‐1 to quit) : ";
cin >> miles; //trip miles input
while( miles ! = ‐1 ) //loops till user enter ‐1
{
cout << "Enter gallons used: ";
cin >> gallons; //used gallons input
//total miles and gallons calculation
totalMiles += miles;
totalGallons += gallons;


//format
thisMPG = static_cast< double > ( miles ) / gallons;
totalMPG = static_cast< double > ( totalMiles ) / totalGallons;
//output
cout << "MPG this trip: " << setprecision( 6 ) << fixed << thisMPG << endl;
cout << "Total MPG: " << totalMPG << endl;
cout << "\nEnter miles driven (‐1 to quit) : ";
cin >> miles; //trip miles input
}
return 0;
}

# %% [markdown]
# # question 4

# %% [markdown]
# # question 5

# %% [markdown]
# # question 6

# %%
def get_dict(items):
    """Function gets an input of list and returns a dictionary containing the type and value of the list items"""
    my_dict = dict() # Create a clear dictionary
    for item in items: # Iterate through the items of the list
        type_name = type(item).__name__ # Get the item type of the item in the list
        if type_name not in my_dict: # Check if the item is already in the dictionary
            my_dict[type_name] = [item] # As its not there so its added as a new value with new key
        else:
            my_dict[type_name].append(item)  # As its already found so its appended to the list with the key value added in the step before
    print(my_dict)
    
my_list = [1 ,1.3, 7, 4.4 ,"hi",[0,1],"45"] # My input list
get_dict(my_list) # Activate the function
